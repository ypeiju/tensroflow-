# %%
import tensorflow as tf
import numpy as np
from sklearn.utils import shuffle
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
trainsamples = 200
testsamples = 60

#Here we will represent the model, a simple imput, a hidden layer of sigmoid activation
def model(X, hidden_weights1, hidden_bias1, ow):
    hidden_layer =  tf.nn.sigmoid(tf.matmul(X, hidden_weights1)+ b) 
    return tf.matmul(hidden_layer, ow)   

dsX = np.linspace(-1, 1, trainsamples + testsamples,dtype=np.float32).transpose()
dsY = 0.4* pow(dsX,2) +2 * dsX + np.random.randn(*dsX.shape) * 0.2 + 0.8 
dsXt=dsX
plt.figure() # Create a new figure
plt.title('Original data')
plt.scatter(dsX,dsY) #Plot a scatter draw of the  datapoints

# %%
X = tf.placeholder("float")
Y = tf.placeholder("float")

hw1 = tf.Variable(tf.random_normal([1, 10], stddev=0.01)) # Create first hidden layer
ow = tf.Variable(tf.random_normal([10, 1], stddev=0.01)) # Create output connection
b = tf.Variable(tf.random_normal([10], stddev=0.01)) # Create bias

model_y = model(X, hw1, b, ow) #

cost = tf.pow(model_y-Y, 2)/(2) # Cost function

train_op = tf.train.AdamOptimizer(0.0001).minimize(cost) # construct an optimizer

# %%
# Launch the graph in a session
with tf.Session() as sess:
    tf.global_variables_initializer().run() #Initialize all variables
    tf.train.write_graph(sess.graph, './graphs','graph.pbtxt')
    writer = tf.summary.FileWriter('./graphs', sess.graph)
    for i in range(1,2000):
        
        trainX, trainY =dsX[0:trainsamples], dsY[0:trainsamples]
        for x1,y1 in zip (trainX, trainY):
            sess.run(train_op, feed_dict={X: [[x1]], Y: y1})
            
        testX, testY = dsX[trainsamples:trainsamples + testsamples], dsY[trainsamples:trainsamples+testsamples]
        cost1=0.
        for x1,y1 in zip (testX, testY):
            #print([[x1]],y1)
            cost1 += sess.run(cost, feed_dict={X: [[x1]], Y: y1}) / testsamples       
        print( "Average cost for epoch " + str (i) + ":" + str(cost1))
        dsX, dsY = shuffle (dsX, dsY) #We randomize the samples to implement a better training            
    dsX2=tf.reshape(dsXt,[trainsamples + testsamples,1])
    dsY2= model(dsX2, hw1, b, ow)
#    dsY2=tf.reshape(dsY2,[1,trainsamples + testsamples])
#    print(sess.run(dsY2))
#    print(dsX2)
    plt.figure() # Create a new figure
    plt.title('Original data')
    plt.scatter(dsX,dsY) #Plot a scatter draw of the  datapoints
    plt.plot(sess.run(dsX2),sess.run(dsY2),'r-',lw=5)
# Out:
# Average cost for epoch 1:[[0.87354636]]
# Average cost for epoch 2:[[0.9779928]]
# Average cost for epoch 3:[[0.96371686]]
# Average cost for epoch 4:[[0.899628]]
# Average cost for epoch 5:[[0.6628819]]
# Average cost for epoch 6:[[0.8103608]]
# Average cost for epoch 7:[[0.7867503]]
# Average cost for epoch 8:[[0.67011327]]
# Average cost for epoch 9:[[0.80359685]]
# Average cost for epoch 10:[[0.72808516]]
# Average cost for epoch 11:[[0.5957284]]
# Average cost for epoch 12:[[0.6246228]]
# Average cost for epoch 13:[[0.50512975]]
# Average cost for epoch 14:[[0.67412066]]
# Average cost for epoch 15:[[0.620036]]
# Average cost for epoch 16:[[0.7234194]]
# Average cost for epoch 17:[[0.5681964]]
# Average cost for epoch 18:[[0.5868949]]
# Average cost for epoch 19:[[0.6025908]]
# Average cost for epoch 20:[[0.4862884]]
# Average cost for epoch 21:[[0.5346898]]
# Average cost for epoch 22:[[0.6213134]]
# Average cost for epoch 23:[[0.6398872]]
# Average cost for epoch 24:[[0.5501307]]
# Average cost for epoch 25:[[0.5630098]]
# Average cost for epoch 26:[[0.6149971]]
# Average cost for epoch 27:[[0.44626763]]
# Average cost for epoch 28:[[0.52703065]]
# Average cost for epoch 29:[[0.61913615]]
# Average cost for epoch 30:[[0.57664853]]
# Average cost for epoch 31:[[0.46955156]]
# Average cost for epoch 32:[[0.4972141]]
# Average cost for epoch 33:[[0.5628528]]
# Average cost for epoch 34:[[0.53046525]]
# Average cost for epoch 35:[[0.4518908]]
# Average cost for epoch 36:[[0.54245514]]
# Average cost for epoch 37:[[0.56608593]]
# Average cost for epoch 38:[[0.45472965]]
# Average cost for epoch 39:[[0.5439941]]
# Average cost for epoch 40:[[0.4687198]]
# Average cost for epoch 41:[[0.5517545]]
# Average cost for epoch 42:[[0.42559263]]
# Average cost for epoch 43:[[0.46793652]]
# Average cost for epoch 44:[[0.43552232]]
# Average cost for epoch 45:[[0.45468032]]
# Average cost for epoch 46:[[0.4626631]]
# Average cost for epoch 47:[[0.49714288]]
# Average cost for epoch 48:[[0.41077834]]
# Average cost for epoch 49:[[0.45730665]]
# Average cost for epoch 50:[[0.4652267]]
# Average cost for epoch 51:[[0.3615377]]
# Average cost for epoch 52:[[0.44441152]]
# Average cost for epoch 53:[[0.4627185]]
# Average cost for epoch 54:[[0.45276704]]
# Average cost for epoch 55:[[0.44141546]]
# Average cost for epoch 56:[[0.3705724]]
# Average cost for epoch 57:[[0.31913713]]
# Average cost for epoch 58:[[0.40586627]]
# Average cost for epoch 59:[[0.4315074]]
# Average cost for epoch 60:[[0.35902452]]
# Average cost for epoch 61:[[0.35431457]]
# Average cost for epoch 62:[[0.4429538]]
# Average cost for epoch 63:[[0.34307232]]
# Average cost for epoch 64:[[0.3960037]]
# Average cost for epoch 65:[[0.33623683]]
# Average cost for epoch 66:[[0.36026928]]
# Average cost for epoch 67:[[0.40134382]]
# Average cost for epoch 68:[[0.44600853]]
# Average cost for epoch 69:[[0.35265398]]
# Average cost for epoch 70:[[0.35728398]]
# Average cost for epoch 71:[[0.34907013]]
# Average cost for epoch 72:[[0.2955013]]
# Average cost for epoch 73:[[0.35753763]]
# Average cost for epoch 74:[[0.4017915]]
# Average cost for epoch 75:[[0.32506442]]
# Average cost for epoch 76:[[0.2504115]]
# Average cost for epoch 77:[[0.33720273]]
# Average cost for epoch 78:[[0.35368]]
# Average cost for epoch 79:[[0.33756605]]
# Average cost for epoch 80:[[0.3476357]]
# Average cost for epoch 81:[[0.30542487]]
# Average cost for epoch 82:[[0.29444498]]
# Average cost for epoch 83:[[0.32388574]]
# Average cost for epoch 84:[[0.291259]]
# Average cost for epoch 85:[[0.26631477]]
# Average cost for epoch 86:[[0.33678424]]
# Average cost for epoch 87:[[0.30260447]]
# Average cost for epoch 88:[[0.3526445]]
# Average cost for epoch 89:[[0.2907137]]
# Average cost for epoch 90:[[0.32132307]]
# Average cost for epoch 91:[[0.24564832]]
# Average cost for epoch 92:[[0.27499512]]
# Average cost for epoch 93:[[0.291538]]
# Average cost for epoch 94:[[0.25199857]]
# Average cost for epoch 95:[[0.29537886]]
# Average cost for epoch 96:[[0.22618215]]
# Average cost for epoch 97:[[0.24670418]]
# Average cost for epoch 98:[[0.23544203]]
# Average cost for epoch 99:[[0.2797752]]
# Average cost for epoch 100:[[0.30817208]]
# Average cost for epoch 101:[[0.28020158]]
# Average cost for epoch 102:[[0.2308668]]
# Average cost for epoch 103:[[0.20477672]]
# Average cost for epoch 104:[[0.23301537]]
# Average cost for epoch 105:[[0.22477028]]
# Average cost for epoch 106:[[0.2721427]]
# Average cost for epoch 107:[[0.25560844]]
# Average cost for epoch 108:[[0.16683324]]
# Average cost for epoch 109:[[0.2897332]]
# Average cost for epoch 110:[[0.2179259]]
# Average cost for epoch 111:[[0.2534662]]
# Average cost for epoch 112:[[0.22265072]]
# Average cost for epoch 113:[[0.22329149]]
# Average cost for epoch 114:[[0.24917325]]
# Average cost for epoch 115:[[0.1845796]]
# Average cost for epoch 116:[[0.16482367]]
# Average cost for epoch 117:[[0.1980556]]
# Average cost for epoch 118:[[0.21556918]]
# Average cost for epoch 119:[[0.23464563]]
# Average cost for epoch 120:[[0.2102638]]
# Average cost for epoch 121:[[0.20082724]]
# Average cost for epoch 122:[[0.14893733]]
# Average cost for epoch 123:[[0.2243267]]
# Average cost for epoch 124:[[0.24024123]]
# Average cost for epoch 125:[[0.21649171]]
# Average cost for epoch 126:[[0.17853592]]
# Average cost for epoch 127:[[0.16932105]]
# Average cost for epoch 128:[[0.20216265]]
# Average cost for epoch 129:[[0.22353373]]
# Average cost for epoch 130:[[0.17395441]]
# Average cost for epoch 131:[[0.1872882]]
# Average cost for epoch 132:[[0.17194545]]
# Average cost for epoch 133:[[0.15031815]]
# Average cost for epoch 134:[[0.18183036]]
# Average cost for epoch 135:[[0.15308549]]
# Average cost for epoch 136:[[0.17883517]]
# Average cost for epoch 137:[[0.17022197]]
# Average cost for epoch 138:[[0.1553002]]
# Average cost for epoch 139:[[0.15138409]]
# Average cost for epoch 140:[[0.1669023]]
# Average cost for epoch 141:[[0.13608763]]
# Average cost for epoch 142:[[0.15726857]]
# Average cost for epoch 143:[[0.14170745]]
# Average cost for epoch 144:[[0.16724303]]
# Average cost for epoch 145:[[0.12763865]]
# Average cost for epoch 146:[[0.14645836]]
# Average cost for epoch 147:[[0.19530538]]
# Average cost for epoch 148:[[0.13433284]]
# Average cost for epoch 149:[[0.13591789]]
# Average cost for epoch 150:[[0.15209281]]
# Average cost for epoch 151:[[0.1245096]]
# Average cost for epoch 152:[[0.14511937]]
# Average cost for epoch 153:[[0.14309074]]
# Average cost for epoch 154:[[0.12415155]]
# Average cost for epoch 155:[[0.09384988]]
# Average cost for epoch 156:[[0.08546199]]
# Average cost for epoch 157:[[0.1350241]]
# Average cost for epoch 158:[[0.12056053]]
# Average cost for epoch 159:[[0.1503255]]
# Average cost for epoch 160:[[0.1520843]]
# Average cost for epoch 161:[[0.0946031]]
# Average cost for epoch 162:[[0.10682949]]
# Average cost for epoch 163:[[0.12249546]]
# Average cost for epoch 164:[[0.11519235]]
# Average cost for epoch 165:[[0.12964135]]
# Average cost for epoch 166:[[0.08709269]]
# Average cost for epoch 167:[[0.13024303]]
# Average cost for epoch 168:[[0.11504517]]
# Average cost for epoch 169:[[0.07392384]]
# Average cost for epoch 170:[[0.10230174]]
# Average cost for epoch 171:[[0.08961402]]
# Average cost for epoch 172:[[0.07737637]]
# Average cost for epoch 173:[[0.09972455]]
# Average cost for epoch 174:[[0.08053419]]
# Average cost for epoch 175:[[0.09346946]]
# Average cost for epoch 176:[[0.09104358]]
# Average cost for epoch 177:[[0.10717665]]
# Average cost for epoch 178:[[0.10502932]]
# Average cost for epoch 179:[[0.1041648]]
# Average cost for epoch 180:[[0.09312978]]
# Average cost for epoch 181:[[0.08855808]]
# Average cost for epoch 182:[[0.11087088]]
# Average cost for epoch 183:[[0.08281096]]
# Average cost for epoch 184:[[0.08266962]]
# Average cost for epoch 185:[[0.09486473]]
# Average cost for epoch 186:[[0.08486725]]
# Average cost for epoch 187:[[0.08930423]]
# Average cost for epoch 188:[[0.0712001]]
# Average cost for epoch 189:[[0.08917908]]
# Average cost for epoch 190:[[0.09604209]]
# Average cost for epoch 191:[[0.08351949]]
# Average cost for epoch 192:[[0.11251448]]
# Average cost for epoch 193:[[0.07382446]]
# Average cost for epoch 194:[[0.06506333]]
# Average cost for epoch 195:[[0.08297386]]
# Average cost for epoch 196:[[0.08100626]]
# Average cost for epoch 197:[[0.06075764]]
# Average cost for epoch 198:[[0.08399148]]
# Average cost for epoch 199:[[0.09152142]]
# Average cost for epoch 200:[[0.07729317]]
# Average cost for epoch 201:[[0.08076734]]
# Average cost for epoch 202:[[0.05863652]]
# Average cost for epoch 203:[[0.08319635]]
# Average cost for epoch 204:[[0.05621144]]
# Average cost for epoch 205:[[0.07713503]]
# Average cost for epoch 206:[[0.06088205]]
# Average cost for epoch 207:[[0.08311478]]
# Average cost for epoch 208:[[0.07415954]]
# Average cost for epoch 209:[[0.08705549]]
# Average cost for epoch 210:[[0.08879656]]
# Average cost for epoch 211:[[0.08169263]]
# Average cost for epoch 212:[[0.07312852]]
# Average cost for epoch 213:[[0.05875714]]
# Average cost for epoch 214:[[0.0618056]]
# Average cost for epoch 215:[[0.07445545]]
# Average cost for epoch 216:[[0.05766005]]
# Average cost for epoch 217:[[0.04358102]]
# Average cost for epoch 218:[[0.0710195]]
# Average cost for epoch 219:[[0.09562892]]
# Average cost for epoch 220:[[0.09620363]]
# Average cost for epoch 221:[[0.06107366]]
# Average cost for epoch 222:[[0.08351748]]
# Average cost for epoch 223:[[0.05389852]]
# Average cost for epoch 224:[[0.09117632]]
# Average cost for epoch 225:[[0.10238906]]
# Average cost for epoch 226:[[0.06064697]]
